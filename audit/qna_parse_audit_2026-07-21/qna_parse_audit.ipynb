# %% [markdown]
# # RAGFlow Q&A 解析质量审计
#
# 只读检查全部启用 Q&A 解析器的知识库文档，对比源 DOCX、当前解析器输出与 Elasticsearch 实际 chunk。

# %%
from qna_parse_audit import run_audit
audit = run_audit()
audit['summary']

# %%
import pandas as pd
pd.DataFrame(audit['documents'])
